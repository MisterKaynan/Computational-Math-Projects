# %%
# !nvidia-smi
# Out:
# Sat Aug 27 14:32:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.94       Driver Version: 516.94       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:06:00.0 Off |                  N/A |
# | N/A   54C    P8    N/A /  N/A |      0MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np

# create data of complex numbers using numpy
data = np.arange(8) + 1j*np.arange(-4, 4)

# extract real part using numpy
x = data.real
# extract imaginary part using numpy
y = data.imag

# plot the complex numbers
plt.figure(figsize=(10,8)) 
plt.plot(x, y, '-.r*', )
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.show()

# %%
G = 121451
g = 12
pi = 3.14214
e = 2.71828
radius = g

# %%
print(dir(__builtin__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
import matplotlib.pyplot as plt
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = np.sin(xx**4 + yy**2) / (xx**3 + yy**2)
plt.figure(figsize=(10,8)) 
h = plt.contourf(x, y, z)
plt.axis('scaled')
plt.show()

# %%
# import matplotlib.pyplot as plt
# from math import sqrt
# x = np.arange(-5, 5, 0.1)
# y = sqrt(abs(x))-sqrt(1-x**2)
# xx, yy = np.meshgrid(x, y, sparse=True)
# z = sqrt(abs(x))-sqrt(1-x**2)
# plt.figure(figsize=(10,8)) 
# h = plt.contourf(x, y, z)
# plt.axis('scaled')
# plt.show()

# %%
import matplotlib.pyplot as plt
from cmath import * 
from pylab import *
golden = (1 + 5 ** 0.5) / 2
# rea = np.arange(-2, 2, 0.1)
# com = np.arange(-2, 2, 0.1) *1+1j
# xx, yy = np.meshgrid(com, com, sparse=True)
# z = (xx+yy)**2 + (1-golden)

# plt.figure(figsize=(10,8)) 
# h = plt.contourf(xx, yy, z)
# plt.axis('scaled')
# imshow(abs(z)<5)

# %%
# import matplotlib.pyplot as plt
# from cmath import * 
# from pylab import *
golden = (1 + 5 ** 0.5) / 2
rea = np.arange(-2, 2, 1)
xx, yy = np.meshgrid(rea, rea, sparse=True)
z = xx+yy*1j
z = z**2 + (1-golden)

plt.figure(figsize=(10,8)) 
# h = plt.contourf(rea, , z)
plt.axis('scaled')
imshow(abs(z)>=1)

# %%
x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = z**2 + (1 - golden)
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 100)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/4151382931.py:6: RuntimeWarning: overflow encountered in square
#   z = z**2 + (1 - golden)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/4151382931.py:6: RuntimeWarning: invalid value encountered in square
#   z = z**2 + (1 - golden)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/4151382931.py:8: RuntimeWarning: overflow encountered in absolute
#   imshow(abs(z) >= 100)

# %%
# golden = (1 + 5 ** 0.5) / 2
# real = np.arange(-2, 2, 0.1)
# ima = np.arange(-2j, 2j, 0.1)
# xx, yy = np.meshgrid(real, ima, sparse=True)
# z1 = z**2 + (-0.4+0.6j)
# plt.figure(figsize=(12,10)) 
# h = plt.contourf(x, y, z1)
# plt.axis('scaled')
# imshow(abs(z1)>=1)

# %%
x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = z**2 + (-0.4+0.6j)
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2094965195.py:6: RuntimeWarning: overflow encountered in square
#   z = z**2 + (-0.4+0.6j)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2094965195.py:6: RuntimeWarning: invalid value encountered in square
#   z = z**2 + (-0.4+0.6j)

# %%
# golden = (1 + 5 ** 0.5) / 2
# real = np.arange(-2, 2, 0.1)
# ima = np.arange(-2j, 2j, 0.1)
# xx, yy = np.meshgrid(real, ima, sparse=True)
# z1 = z**2 + (0.8+0.156j)
# plt.figure(figsize=(12,10)) 
# h = plt.contourf(x, y, z1)
# plt.axis('scaled')
# imshow(abs(z1)>=1)

# %%
x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = z**2 + (-0.8+0.156j)
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3764802285.py:6: RuntimeWarning: overflow encountered in square
#   z = z**2 + (-0.8+0.156j)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3764802285.py:6: RuntimeWarning: invalid value encountered in square
#   z = z**2 + (-0.8+0.156j)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3764802285.py:8: RuntimeWarning: overflow encountered in absolute
#   imshow(abs(z) >= 2)

# %%
# golden = (1 + 5 ** 0.5) / 2
# real = np.arange(-2, 2, 0.1)
# ima = np.arange(-2j, 2j, 0.1)
# xx, yy = np.meshgrid(real, ima, sparse=True)
# z1 = z**2 + (0.285+0.1j)
# plt.figure(figsize=(12,10)) 
# h = plt.contourf(x, y, z1)
# plt.axis('scaled')
# plt.imshow 
# while abs(z1) >=2:
#     plt.show()

# %%
x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = z**2 + (0.285+0.1j)
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/99195900.py:6: RuntimeWarning: overflow encountered in square
#   z = z**2 + (0.285+0.1j)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/99195900.py:6: RuntimeWarning: invalid value encountered in square
#   z = z**2 + (0.285+0.1j)
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/99195900.py:8: RuntimeWarning: overflow encountered in absolute
#   imshow(abs(z) >= 2)

# %%
x = linspace(-2,2,201)

xx,y = meshgrid (x,x)
z = xx+y*1j
for i in range (10):
    z = z**4 + 0.484
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/1984140581.py:6: RuntimeWarning: overflow encountered in power
#   z = z**4 + 0.484
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/1984140581.py:6: RuntimeWarning: invalid value encountered in power
#   z = z**4 + 0.484

# %%
from math import e as e

x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = z*e**z + 0.04
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2129719527.py:8: RuntimeWarning: overflow encountered in power
#   z = z*e**z + 0.04
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2129719527.py:8: RuntimeWarning: overflow encountered in multiply
#   z = z*e**z + 0.04
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2129719527.py:8: RuntimeWarning: invalid value encountered in multiply
#   z = z*e**z + 0.04
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/2129719527.py:8: RuntimeWarning: invalid value encountered in power
#   z = z*e**z + 0.04

# %%
from numpy import sqrt, sinh

x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = sqrt(sinh(z**4)) + 0.065+0.122j
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3452809704.py:8: RuntimeWarning: overflow encountered in sinh
#   z = sqrt(sinh(z**4)) + 0.065+0.122j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3452809704.py:8: RuntimeWarning: overflow encountered in power
#   z = sqrt(sinh(z**4)) + 0.065+0.122j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3452809704.py:8: RuntimeWarning: invalid value encountered in power
#   z = sqrt(sinh(z**4)) + 0.065+0.122j

# %%
x = linspace(-2,2,201)

x,y = meshgrid (x,x)
z = x+y*1j
for i in range (10):
    z = ((z**2 + z)/np.log(z)) +0.268+0.060j
plt.figure(figsize=(10,8)) 
imshow(abs(z) >= 2)
# Out:
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: divide by zero encountered in log
#   z = ((z**2 + z)/np.log(z)) +0.268+0.060j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: divide by zero encountered in true_divide
#   z = ((z**2 + z)/np.log(z)) +0.268+0.060j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: invalid value encountered in true_divide
#   z = ((z**2 + z)/np.log(z)) +0.268+0.060j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: invalid value encountered in log
#   z = ((z**2 + z)/np.log(z)) +0.268+0.060j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: overflow encountered in square
#   z = ((z**2 + z)/np.log(z)) +0.268+0.060j
# C:\Users\MISTER~1\AppData\Local\Temp/ipykernel_23924/3611954550.py:6: RuntimeWarning: invalid value encountered in square
# ...
